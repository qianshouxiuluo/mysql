# %% [markdown]
# # 基本程序设计
# - 一切代码输入，请使用英文输入法

# %%
print('hello word')
# Out:
# hello word

# %%
print 'hello'
# Out:
#   File "<ipython-input-2-5a1ef41e7057>", line 1
#     print 'hello'
#                 ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('hello')?

# %% [markdown]
# ## 编写一个简单的程序
# - 圆公式面积： area = radius \* radius \* 3.1415

# %%
radius = 1.0
area = radius * radius * 3.14 # 将后半部分的结果赋值给变量area
# 变量一定要有初始值！！！
# radius: 变量.area: 变量！
# int 类型
print(area)
# Out:
# 3.14

# %%
x = eval(input('x'))
res = eval(input('输入表达式: '))
print('res')
# Out:
# x10
# 输入表达式: 3.1*x**2+2*x+100
# res

# %% [markdown]
# ### 在Python里面不需要定义数据的类型

# %% [markdown]
# ## 控制台的读取与输入
# - input 输入进去的是字符串
# - eval

# %%
radius = input('请输入半径') # input得到的结果是字符串类型
radius = float(radius)
area = radius * radius * 3.14
print('面积为:',area)
# Out:
# 请输入半径10
# 面积为: 314.0

# %% [markdown]
# - 在jupyter用shift + tab 键可以跳出解释文档

# %% [markdown]
# ## 变量命名的规范
# - 由字母、数字、下划线构成
# - 不能以数字开头 \*
# - 标识符不能是关键词(实际上是可以强制改变的，但是对于代码规范而言是极其不适合)
# - 可以是任意长度
# - 驼峰式命名

# %% [markdown]
# ## 变量、赋值语句和赋值表达式
# - 变量: 通俗理解为可以变化的量
# - x = 2 \* x + 1 在数学中是一个方程，而在语言中它是一个表达式
# - test = test + 1 \* 变量在赋值之前必须有值

# %% [markdown]
# ## 同时赋值
# var1, var2,var3... = exp1,exp2,exp3...

# %% [markdown]
# ## 定义常量
# - 常量：表示一种定值标识符，适合于多次使用的场景。比如PI
# - 注意：在其他低级语言中如果定义了常量，那么，该常量是不可以被改变的，但是在Python中一切皆对象，常量也是可以被改变的

# %% [markdown]
# ![01.![01.jpg](attachment:01.jpg)jpg](attachment:01.jpg)## 数值数据类型和运算符
# - 在Python中有两种数值类型（int 和 float）适用于加减乘除、模、幂次
# <img src = "Photo/01.jpg"></img>

# %% [markdown]
# ## 运算符 /、//、**

# %% [markdown]
# ## 运算符 %

# %% [markdown]
# ## EP：
# - 25/4 多少，如果要将其转变为整数该怎么改写
# - 输入一个数字判断是奇数还是偶数
# - 进阶: 输入一个秒数，写一个程序将其转换成分和秒：例如500秒等于8分20秒
# - 进阶: 如果今天是星期六，那么10天以后是星期几？ 提示：每个星期的第0天是星期天

# %% [markdown]
# ## 科学计数法
# - 1.234e+2
# - 1.234e-2

# %% [markdown]
# ![03.png](attachment:03.png)![04.png](attachment:04.png)![05.png](attachment:05.png)![06.png](attachment:06.png)## 计算表达式和运算优先级
# <img src = "../Photo/02.png"></img>
# <img src = "../Photo/03.png"></img>

# %% [markdown]
# ## 增强型赋值运算
# <img src = "../Photo/04.png"></img>

# %% [markdown]
# ## 类型转换
# - float  -> int
# - 四舍五入 round

# %% [markdown]
# ## EP:
# - 如果一个年营业税为0.06%，那么对于197.55e+2的年收入，需要交税为多少？(结果保留2为小数)
# - 必须使用科学计数法

# %% [markdown]
# ![05.png](attachment:05.png)# Project
# - 用Python写一个贷款计算器程序：输入的是月供(monthlyPayment) 输出的是总还款数(totalpayment)
# ![](../Photo/05.png)

# %% [markdown]
# ![06.png](attachment:06.png)# Homework
# - 1
# <img src="../Photo/06.png"></img>

# %%
celsius = eval(input())
fahrenheit = (9 / 5) * celsius + 32
print(fahrenheit)
# Out:
# 43
# 109.4

# %% [markdown]
# ![07.png](attachment:07.png)- 2
# <img src="../Photo/07.png"></img>

# %%
radius = eval(input())
length = eval(input())
Π = 3.1415926
area = radius * radius * Π
volume = area * length
print(round(area,4))
print(round(volume,1))
# Out:
# 5.5
# 12
# 95.0332
# 1140.4

# %% [markdown]
# ![08.png](attachment:08.png)- 3
# <img src="../Photo/08.png"></img>

# %%
feet = eval(input())
meters = 0.305 * feet
print(meters)
# Out:
# 16.5
# 5.0325

# %% [markdown]
# - 4
# <img src="../Photo/10.png"></img>

# %%
kilograms = eval(input())
initial = eval(input())
final = eval( input())
Q = kilograms * (final - initial) * 4184
print(Q)
# Out:
# 55.5
# 3.5
# 10.5
# 1625484.0

# %% [markdown]
# - 5
# <img src="../Photo/11.png"></img>

# %%
balance = eval(input())
nianlilv = eval(input())
interest = balance * (nianlilv / 1200)
print(interest)
# Out:
# 1000
# 3.5
# 2.916666666666667

# %% [markdown]
# - 6
# <img src="../Photo/12.png"></img>

# %%
v1 = eval(input())
v2 = eval(input())
t = eval(input())
a = (v2 - v1) / t
print(a)

# %% [markdown]
# - 7 进阶
# <img src="../Photo/13.png"></img>

# %% [markdown]
# - 8 进阶
# <img src="../Photo/14.png"></img>

# %%
a,b = eval(input('>>'))
print(a,b)
print(type(a),type(b))

# %%
a = eval(input('>>'))
print(a)
